# %%
#importing the mudules
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#creating the candidates
np.random.seed(42)
n = 10000
x = np.random.rand(n)
y = 2.0 + 3.0 * x + np.random.randn(n)

# %%
#ploting the data
plt.scatter(x, y)
plt.show()

# %%
x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=1)
plt.plot(x, y_pred, color='red')

# Add axis labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')

# Show the plot
plt.show()
